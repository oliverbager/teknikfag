# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("ELISA.csv")

# %%
x = data["Time"]

# %%
concentrations = ["80","40","20","10","5","2.5","1.25","0.625","0.3125","0.15625","0.078125","0.0390625", "0"]

# %%
columns = ['B{}'.format(i) for i in range(1,13)]+["A11"]

# %%
def growthPlot(name, title, cols = [], conc = []):
    fig, name = plt.subplots()
    i = 0
    for e in cols:
        name.plot(x, data[e],label=concentrations[i])
        i += 1

    name.set_title(title)
    name.set_xlabel("Tid [timer]")
    name.set_ylabel("Absorbans")
    plt.subplots_adjust(right=0.77)
    name.legend(loc=(1.04,0.25))
    plt.savefig(str(name)+".pdf", dpi=150)
    
    plt.show()

# %%
growthPlot('vækstbcethyl' ,"Abs(t), cereus, ethylparaben", columns)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
columns = ['C{}'.format(i) for i in range(1,13)]+["A11"]

# %%
growthPlot('vækstbcpropyl' ,"Abs(t), cereus, propylparaben", columns)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
columns = ['F{}'.format(i) for i in range(1,13)]+["E10"]

# %%
growthPlot('vækstbcpropyl' ,"Abs(t), coli, ethylparaben", columns)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
columns = ['G{}'.format(i) for i in range(1,13)]+["E10"]

# %%
growthPlot('vækstbcpropyl' ,"Abs(t), coli, propylparaben", columns)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nconcentrations = list(map(float, concentrations))

# %%
def micPlot(name, a, b, title):
    fig, name = plt.subplots()

    name.plot(nconcentrations, data.iloc[68,a:b].values.tolist()+[data.iloc[68,a-2]])

    name.set_title(title)
    name.set_xlabel("log(c)")
    name.set_ylabel("Absorbans ved 17 timer")
    name.set_xscale('log')
    plt.savefig(str(name)+".pdf", dpi=150)
    
    plt.show()

# %%
micPlot('micbcethyl', 13, 25, "Abs(c), cereus, ethylparaben")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
micPlot('micbcpropyl', 25, 37, "Abs(c), cereus, propylparaben")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
micPlot('micecethyl', 49, 61, "Abs(c), coli, ethylparaben")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
micPlot('micecpropyl', 61, 73, "Abs(c), coli, propylparaben")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
